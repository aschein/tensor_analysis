# %%
ls
# Out:
# #fdsafdas.txt#     build_sparse_tensor_from_mht_data.py  create_drug_dict_RxNorm.py~                        parse_MEDS_MHT_subset.py             resume_reloadTensors_localadmin.py         setup_python_env.py                       wrapper_marble_localadmin.py~
# #fdsafdsaf.py#     create_drug_dict.py                   create_subset_of_allfinite_tensor_forAnalysis.py   parse_MEDS_MHT_subset_localadmin.py  run_analyze_marble_gamma-0.12to0.15.ipynb  sh_wrapper_tensor_experiemnts_marble.sh
# ICD9-2-PheWAS.xls  create_drug_dict.py~                  create_subset_of_allfinite_tensor_forAnalysis.py~  read_pheWAS_dictionary_xls.py        run_factorization_localadmin.py            sh_wrapper_tensor_experiemnts_marble.sh~
# Untitled0.ipynb    create_drug_dict_RxNorm.py            lookupDrug_modRC.py                                read_pheWAS_dictionary_xls.py~       scrape_drugs_joyce/                        wrapper_marble_localadmin.py

# %%
import os
os.getcwd()
# Out:
# '/nv/pcoc1/rchen87/tensor_factorization/github_tensor/htn_data_process_server_backup_20140828'

# %%
import sys

# %%
os.chdir('/nv/pcoc1/rchen87/tensor_factorization/github_tensor/experiment_code/')

# %%
ls
# Out:
# ICD9-2-PheWAS.xls  loadtensor_runfactorization_printphenotypes.py  loadtensor_runfactorization_printphenotypes.py~  read_pheWAS_dictionary_xls.py  read_pheWAS_dictionary_xls.py~  setup_python_env.py  setup_python_env.py~  test_python.py  test_python.py~

# %%
ls -l
# Out:
# total 4012
# -rw-r--r-- 1 rchen87 cc-song 3941376 Aug 29 01:08 ICD9-2-PheWAS.xls
# -rw-r--r-- 1 rchen87 cc-song    9319 Aug 29 02:01 loadtensor_runfactorization_printphenotypes.py
# -rw-r--r-- 1 rchen87 cc-song    9242 Aug 29 01:58 loadtensor_runfactorization_printphenotypes.py~
# -rw-r--r-- 1 rchen87 cc-song     664 Aug 29 01:53 read_pheWAS_dictionary_xls.py
# -rw-r--r-- 1 rchen87 cc-song     846 Aug 29 01:52 read_pheWAS_dictionary_xls.py~
# -rw-r--r-- 1 rchen87 cc-song    1462 Aug 29 01:46 setup_python_env.py
# -rw-r--r-- 1 rchen87 cc-song    1445 Aug 29 01:03 setup_python_env.py~
# -rw-r--r-- 1 rchen87 cc-song     125 Aug 29 01:33 test_python.py
# -rw-r--r-- 1 rchen87 cc-song     107 Aug 29 01:33 test_python.py~

# %%
import sys
# R = int(sys.argv[1])
# alpha = float(sys.argv[2])
# gammaForTF = sys.argv[3]
# tensor_input = sys.argv[4]
# CODE_DIR = sys.argv[5]
# save_folder = sys.argv[6]

R = 50
alpha = 1
gammaForTF = '0.001,0.14,0.14'
tensor_input = '/nv/pcoc1/rchen87/tensor_factorization/github_tensor/htn_data_tensors/htn-tensor-subsetforanalysis-20140811-{0}.dat'
CODE_DIR = '/nv/pcoc1/rchen87/tensor_factorization/github_tensor/experiment_code/'
save_folder = '/nv/pcoc1/rchen87/tensor_factorization/github_tensor/htn_expt_run/output_20140829/'


gammaForTF = gammaForTF.split(',')
gammaForTF = [float(x) for x in gammaForTF]


#load required modules:                                                                                                                                                                                                                                                                                           
print "loading required modules"

execfile( CODE_DIR + 'setup_python_env.py')
pheWAS_xls_file = CODE_DIR + 'ICD9-2-PheWAS.xls'


#create output folder if it does not exist                                                                                                                                                                                                                                                                        
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

#do tensor factorization on the SUBSET - with GAMMA as set above ##################################################################################################                                                                                                                                               
#laod the tensor for the subset!                                                                                                                                                                                                                                                                                  
print "loading tensor data"

loaded_X, loaded_axisDict, loaded_classDict = tensorIO.loadSingleTensor(tensor_input)

startTime = time.time()#start time -- to time it                                                                                                                                                                                                                                                                  
##factorization                                                                                                                                                                                                                                                                                                   
print "running factorization"
spntf_htn_subset_analyzed_withGamma = SP_NTF.SP_NTF(loaded_X, R=R, alpha=alpha)
Yinfo_htn_subset_analyzed_withGamma = spntf_htn_subset_analyzed_withGamma.computeDecomp(gamma=gammaForTF)
marbleElapse = time.time() - startTime #elapsed time                                                                                                                                                                                                                                                              

#tensor decomposition factors ("phenotypes"):                                                                                                                                                                                                                                                                     
pheno_htn_subset_analyzed_withGamma_REG = spntf_htn_subset_analyzed_withGamma.M[0]
pheno_htn_subset_analyzed_withGamma_AUG = spntf_htn_subset_analyzed_withGamma.M[1]
pheno_htn_subset_analyzed_withGamma = (pheno_htn_subset_analyzed_withGamma_REG, pheno_htn_subset_analyzed_withGamma_AUG)


#string for saving the file based upon gamma                                                                                                                                                                                                                                                                      
gamma_str = '_gamma'
for num in gammaForTF:
    gamma_str = gamma_str + '-' + str(num)
gamma_str = gamma_str + '.pickle'

#save factorization in pickle                                                                                                                                                                                                                                                                                     
outfile_str = save_folder + "pheno_htn_subset_analyzed_REG" + gamma_str
with open(outfile_str, "wb") as output_file: ##IMPT! phenotype stored in this pickle                                                                                                                                                                                                                              
    pickle.dump(pheno_htn_subset_analyzed_withGamma, output_file)
output_file.close()
outfile_str = save_folder + "pheno_htn_subset_analyzed_AUG" + gamma_str
with open(outfile_str, "wb") as output_file: ##IMPT! phenotype stored in this pickle                                                                                                                                                                                                                              
    pickle.dump(pheno_htn_subset_analyzed_withGamma, output_file)
output_file.close()
outfile_str = save_folder + "Yinfo_htn_subset_analyzed" + gamma_str
with open(outfile_str, "wb") as output_file:
    pickle.dump(Yinfo_htn_subset_analyzed_withGamma, output_file)
output_file.close()


import operator

def calculateValues(TM, M):
    fms = TM.greedy_fms(M)
    fos = TM.greedy_fos(M)
    nnz = tensorTools.countTensorNNZ(M)
    return fms, fos, nnz

## load the tensor #######                                                                                                                                                                                                                                                                                        
loaded_X, loaded_axisDict, loaded_classDict = tensorIO.loadSingleTensor(tensor_input)

##read in the pickles:                                                                                                                                                                                                                                                                                            

outfile_str = save_folder + "pheno_htn_subset_analyzed_REG" + gamma_str
matrix_pkl = open(outfile_str, "rb")
pheno_htn_subset_analyzed_REG_withGamma = pickle.load(matrix_pkl)
matrix_pkl.close()

outfile_str = save_folder + "Yinfo_htn_subset_analyzed" + gamma_str
matrix_pkl = open(outfile_str, "rb")
Yinfo_htn_subset_analyzed_withGamma = pickle.load(matrix_pkl)
matrix_pkl.close()

#write output file                                                                                                                                                                                                                                                                                                
pheno_outstream = open(save_folder + "phenotypes"+gamma_str+".out", 'w+')


############################################################################################################## 

#load pheWAS dictionary                                                                                                                                                                                                                                                                                           

xls = pd.ExcelFile(pheWAS_xls_file)
df_pheWAS = xls.parse(xls.sheet_names[0])

d_jdrange_lookup = dict(zip(list(df_pheWAS.JD_X_RANGE), list(df_pheWAS.JD_X_NAME)))



#############################################################################################################                                                                                                                                                                                                     


#tensor with all phenotypes (factorization)                                                                                                                                                                                                                                                                       
ktensor_phenotypes = pheno_htn_subset_analyzed_REG_withGamma[0]
l_pts = loaded_axisDict[0].keys()
l_jdrange = loaded_axisDict[1].keys()
l_meds= loaded_axisDict[2].keys()

#will store all the data                                                                                                                                                                                                                                                                                          
d_pheno_nonzero_labels = OrderedDict()


#sort phenotypes by lambda values:                                                                                                                                                                                                                                                                                
d_lambda_phenoNumber = OrderedDict(zip( list(range(R)),
                                        list(ktensor_phenotypes.lmbda)
                                        ))
l_phenoNumbers_sorted_by_lambda = [tup[0] for tup in sorted(d_lambda_phenoNumber.iteritems(), key=operator.itemgetter(1))][::-1]  #get a sorted list of phenotype numbers, which are sorted by using the operator.itemgetter                                                                                      

#print phenotype feature names #################                                                                                                                                                                                                                                                                  
#for i in range(10):                                                 
for i in l_phenoNumbers_sorted_by_lambda:
    print "===== phenotype " + str(i) + "================================================================="
    pheno_outstream.write("===== phenotype " + str(i) + "=================================================================" + '\n')
    this_lmbda = ktensor_phenotypes.lmbda[i]
    this_pheno_pt_factor = ktensor_phenotypes.U[0][:,i]
    this_pheno_jdrange_factor = ktensor_phenotypes.U[1][:,i]
    this_pheno_med_factor = ktensor_phenotypes.U[2][:,i]

    this_pheno_pt_nnz = np.nonzero(this_pheno_pt_factor)[0]
    this_pheno_jdrange_nnz = np.nonzero(this_pheno_jdrange_factor)[0]
    this_pheno_med_nnz = np.nonzero(this_pheno_med_factor)[0]

    l_nonzero_pt_thisPheno = []
    l_nonzero_meds_thisPheno = []
    l_nonzero_jdrange_thisPheno = []
    l_nonzero_jdrange_names_thisPheno = []

    for j in this_pheno_pt_nnz:
        l_nonzero_pt_thisPheno.append(l_pts[j])
    for j in this_pheno_jdrange_nnz:
        l_nonzero_jdrange_thisPheno.append(l_jdrange[j])
        l_nonzero_jdrange_names_thisPheno.append(d_jdrange_lookup[l_jdrange[j]])
    for j in this_pheno_med_nnz:
        l_nonzero_meds_thisPheno.append(l_meds[j])

    #data                                                                                                                                                                                                                                                                                                         
    d_pheno_nonzero_labels[i] = dict() #for phenotype i                                                                                                                                                                                                                                                           
    d_pheno_nonzero_labels[i]['LAMBDA'] = this_lmbda #lambda value                                                                                                                                                                                                                                                
    d_pheno_nonzero_labels[i]['PERCENT_PTS'] = len(l_nonzero_pt_thisPheno) / float(len(this_pheno_pt_factor))
    d_pheno_nonzero_labels[i]['MEDS_NZ'] = l_nonzero_meds_thisPheno #for phenotype i                                                                                                                                                                                                                              
    d_pheno_nonzero_labels[i]['JDRANGE_NZ'] = l_nonzero_jdrange_thisPheno #for phenotype i                                                                                                                                                                                                                        
    d_pheno_nonzero_labels[i]['JDRANGE_NAMES_NZ'] = l_nonzero_jdrange_names_thisPheno #for phenotype i                                                                                                                                                                                                            

    print "proportion of pts: " + str(d_pheno_nonzero_labels[i]['PERCENT_PTS'])
    pheno_outstream.write("proportion of pts: " + str(d_pheno_nonzero_labels[i]['PERCENT_PTS']) + '\n')
    print "lambda: " + str(this_lmbda)
    pheno_outstream.write("lambda: " + str(this_lmbda) + '\n')


    print "----------------------------------------" #divider                                                                                                                                                                                                                                                     
    pheno_outstream.write("----------------------------------------" + '\n')
    #make ranking of JDRANGE by the weights:                                                                                                                                                                                                                                                                      
    nparr_jdrange_weights = this_pheno_jdrange_factor[this_pheno_jdrange_nnz]
    d_jdrangeindex_weights = OrderedDict(zip(this_pheno_jdrange_nnz, nparr_jdrange_weights))
    l_jdrangeindex_sorted = [tup[0] for tup in sorted(d_jdrangeindex_weights.iteritems(), key=operator.itemgetter(1))][::-1] #note: use slice [::-1] to reverse list!                                                                                                                                             
    for index_this_jdrange in l_jdrangeindex_sorted:
        print d_jdrange_lookup[l_jdrange[index_this_jdrange]] + '\t' + str("%.3f" %this_pheno_jdrange_factor[index_this_jdrange] )
        pheno_outstream.write(str(d_jdrange_lookup[l_jdrange[index_this_jdrange]]) + '\t' + str("%.3f" %this_pheno_jdrange_factor[index_this_jdrange])  +'\n')


    print "----------------------------------------" #divider between diagnostic codes and meds                                                                                                                                                                                                                   
    pheno_outstream.write("----------------------------------------" + '\n')
    #make ranking of MED by the weights:                                                                                                                                                                                                                                                                          
    nparr_med_weights = this_pheno_med_factor[this_pheno_med_nnz]
    d_medindex_weights = OrderedDict(zip(this_pheno_med_nnz, nparr_med_weights))
    l_medindex_sorted = [tup[0] for tup in sorted(d_medindex_weights.iteritems(), key=operator.itemgetter(1))][::-1]
    for index_this_med in l_medindex_sorted:
        print l_meds[index_this_med]  + '\t' + str("%.3f" %this_pheno_med_factor[index_this_med])
        pheno_outstream.write(l_meds[index_this_med]  + '\t' + str("%.3f" %this_pheno_med_factor[index_this_med]) + '\n')
pheno_outstream.close()
# Out:
# loading required modules
# loading tensor data
# running factorization
# Iteration 0: Xi = 0.256559741996, dll = 5765267.98192, time = 372.459392071
# Iteration 1: Xi = 0.513797386702, dll = 1804307.44051, time = 374.916966915
# Iteration 2: Xi = 0.587346549435, dll = 4043354.74817, time = 363.18897891
# Iteration 3: Xi = 0.789889220034, dll = 90927.5005171, time = 359.648455143
# Iteration 4: Xi = 0.866409622584, dll = 727170.195249, time = 366.55875206
# Iteration 5: Xi = 0.926942509265, dll = 161609.21118, time = 366.890021086
# Iteration 6: Xi = 0.959773437042, dll = 96139.3993065, time = 361.673806906
# Iteration 7: Xi = 0.978140874634, dll = 45549.1630344, time = 366.319643974
# Iteration 8: Xi = 0.987828741233, dll = 32476.5711997, time = 365.153172016
# Iteration 9: Xi = 0.993171249914, dll = 19465.2580823, time = 365.066636086
# Iteration 10: Xi = 0.996489094321, dll = 2529.00582879, time = 403.197201967
# Iteration 11: Xi = 0.998237225003, dll = 191.835991271, time = 391.254063129
# Iteration 12: Xi = 0.999095952854, dll = 593.695632961, time = 396.854566097
# Iteration 13: Xi = 0.999547944111, dll = 0.846684789285, time = 399.081261873
# Iteration 14: Xi = 0.999770417701, dll = 93.1267729327, time = 400.069339991
# Iteration 15: Xi = 0.999885205814, dll = 0.0795433279127, time = 397.223638058
# Iteration 16: Xi = 0.99994260286, dll = 0.00123023986816, time = 398.279306889
# ===== phenotype 28=================================================================
# proportion of pts: 0.199920666402
# lambda: 9462.78106893
# ----------------------------------------
# Range name na	0.222
# Hypertensive disease	0.214
# Disorders of the eye and adnexa	0.199
# Disorders of lipoid metabolism	0.196
# General symptoms	0.169
# ----------------------------------------
# Fibrinolytic Agents	0.188
# Antipyretics	0.172
# Cyclooxygenase Inhibitors	0.167
# Platelet Aggregation Inhibitors	0.164
# Anti-Inflammatory Agents, Non-Steroidal	0.155
# Hydroxymethylglutaryl-CoA Reductase Inhibitors	0.154
# ===== phenotype 17=================================================================
# proportion of pts: 0.171360571202
# lambda: 7026.27791851
# ----------------------------------------
# Other forms of heart disease	0.236
# Hypertensive disease	0.233
# Range name na	0.212
# Disorders of lipoid metabolism	0.177
# Symptoms involving respiratory system and other chest symptoms	0.143
# ----------------------------------------
# Anti-Arrhythmia Agents	0.188
# Antihypertensive Agents	0.184
# Anticoagulants	0.169
# Sympatholytics	0.166
# Rodenticides	0.153
# Vasodilator Agents	0.140
# ===== phenotype 21=================================================================
# proportion of pts: 0.181277270924
# lambda: 7000.02191692
# ----------------------------------------
# Disorders of lipoid metabolism	0.264
# Diabetes	0.213
# Symptoms involving respiratory system and other chest symptoms	0.188
# Arthropathies and related disorders	0.180
# Rheumatism, excluding the back	0.156
# ----------------------------------------
# Anti-Arrhythmia Agents	0.184
# Hydroxymethylglutaryl-CoA Reductase Inhibitors	0.168
# Anticholesteremic Agents	0.167
# Sympatholytics	0.161
# Adrenergic beta-1 Receptor Antagonists	0.160
# Hypolipidemic Agents	0.160
# ===== phenotype 36=================================================================
# proportion of pts: 0.174137247124
# lambda: 6973.67504275
# ----------------------------------------
# Hypertensive disease	0.212
# Range name na	0.208
# Arthropathies and related disorders	0.200
# Dorsopathies	0.196
# Rheumatism, excluding the back	0.185
# ----------------------------------------
# Antihypertensive Agents	0.185
# Analgesics, Non-Narcotic	0.172
# Antipyretics	0.171
# Anti-Inflammatory Agents, Non-Steroidal	0.165
# Cyclooxygenase Inhibitors	0.160
# Angiotensin-Converting Enzyme Inhibitors	0.146
# ===== phenotype 49=================================================================
# proportion of pts: 0.189607298691
# lambda: 6841.38534309
# ----------------------------------------
# Range name na	0.188
# Arthropathies and related disorders	0.174
# Rheumatism, excluding the back	0.170
# Hypertensive disease	0.167
# Dorsopathies	0.158
# General symptoms	0.144
# ----------------------------------------
# Anti-Allergic Agents	0.219
# Bronchodilator Agents	0.204
# Anti-Inflammatory Agents	0.194
# Vitamins	0.192
# Bone Density Conservation Agents	0.190
# ===== phenotype 7=================================================================
# proportion of pts: 0.166997223324
# lambda: 6049.61276834
# ----------------------------------------
# Hypertensive disease	0.284
# Disorders of lipoid metabolism	0.268
# Acute respiratory infections	0.225
# Symptoms involving respiratory system and other chest symptoms	0.223
# ----------------------------------------
# Fibrinolytic Agents	0.182
# Antipyretics	0.173
# Cyclooxygenase Inhibitors	0.173
# Anti-Inflammatory Agents, Non-Steroidal	0.167
# Platelet Aggregation Inhibitors	0.162
# Antihypertensive Agents	0.143
# ===== phenotype 47=================================================================
# proportion of pts: 0.180880602935
# lambda: 5807.60589939
# ----------------------------------------
# Hypertensive disease	0.197
# Symptoms involving respiratory system and other chest symptoms	0.178
# Disorders of lipoid metabolism	0.167
# Diseases of esophagus, stomach, and duodenum	0.165
# Other diseases of the upper respiratory tract	0.151
# Acute respiratory infections	0.143
# ----------------------------------------
# Histamine H1 Antagonists, Non-Sedating	0.206
# Bronchodilator Agents	0.205
# Proton Pump Inhibitors	0.205
# Anti-Ulcer Agents	0.198
# Anti-Allergic Agents	0.186
# ===== phenotype 46=================================================================
# proportion of pts: 0.173343911146
# lambda: 5787.89874447
# ----------------------------------------
# Hypertensive disease	0.221
# Rheumatism, excluding the back	0.217
# Disorders of lipoid metabolism	0.195
# Arthropathies and related disorders	0.193
# Dorsopathies	0.174
# ----------------------------------------
# Fibrinolytic Agents	0.235
# Platelet Aggregation Inhibitors	0.222
# Cyclooxygenase Inhibitors	0.205
# Anti-Inflammatory Agents, Non-Steroidal	0.195
# Diuretics	0.143
# ===== phenotype 5=================================================================
# proportion of pts: 0.177707259024
# lambda: 5731.52797486
# ----------------------------------------
# Nutritional deficiencies	0.224
# Diabetes	0.219
# General symptoms	0.209
# Disorders of lipoid metabolism	0.196
# Na	0.152
# ----------------------------------------
# Antihypertensive Agents	0.191
# Cyclooxygenase Inhibitors	0.170
# Anti-Inflammatory Agents, Non-Steroidal	0.168
# Antipyretics	0.167
# Vitamins	0.155
# Bone Density Conservation Agents	0.149
# ===== phenotype 9=================================================================
# proportion of pts: 0.157477191591
# lambda: 5689.63401724
# ----------------------------------------
# Hypertensive disease	0.245
# Ischemic heart disease	0.231
# Disorders of lipoid metabolism	0.213
# Diseases of arteries, arterioles, and capillaries	0.160
# Cerebrovascular disease	0.150
# ----------------------------------------
# Antipyretics	0.184
# Anticholesteremic Agents	0.177
# Hydroxymethylglutaryl-CoA Reductase Inhibitors	0.171
# Platelet Aggregation Inhibitors	0.167
# Cyclooxygenase Inhibitors	0.160
# Anti-Inflammatory Agents, Non-Steroidal	0.141
# ===== phenotype 32=================================================================
# proportion of pts: 0.169773899246
# lambda: 5670.83276929
# ----------------------------------------
# Hypertensive disease	0.268
# Disorders of lipoid metabolism	0.218
# General symptoms	0.180
# Range name na	0.173
# Dorsopathies	0.162
# ----------------------------------------
# Anti-Anxiety Agents	0.200
# Muscle Relaxants, Central	0.167
# Anticonvulsants	0.164
# GABA Modulators	0.163
# Antidepressive Agents, Tricyclic	0.155
# Hypnotics and Sedatives	0.152
# ===== phenotype 16=================================================================
# proportion of pts: 0.186830622769
# lambda: 5596.0791088
# ----------------------------------------
# Hypertensive disease	0.234
# Diabetes	0.207
# Disorders of lipoid metabolism	0.207
# Rheumatism, excluding the back	0.179
# Arthropathies and related disorders	0.173
# ----------------------------------------
# Anticholesteremic Agents	0.271
# Hydroxymethylglutaryl-CoA Reductase Inhibitors	0.260
# Antihypertensive Agents	0.251
# Antipyretics	0.218
# ===== phenotype 30=================================================================
# proportion of pts: 0.128520428401
# lambda: 5160.97871259
# ----------------------------------------
# Hypertensive disease	0.273
# Dorsopathies	0.216
# Diabetes	0.181
# Symptoms involving respiratory system and other chest symptoms	0.173
# Disorders of the peripheral nervous system	0.157
# ----------------------------------------
# Analgesics	0.184
# Anticonvulsants	0.167
# Excitatory Amino Acid Antagonists	0.164
# Calcium Channel Blockers	0.163
# Antiparkinson Agents	0.162
# Antimanic Agents	0.159
# ===== phenotype 31=================================================================
# proportion of pts: 0.151130503768
# lambda: 5118.1473258
# ----------------------------------------
# Chronic obstructive pulmonary disease and allied conditions	0.226
# Hypertensive disease	0.217
# Symptoms involving respiratory system and other chest symptoms	0.201
# Disorders of lipoid metabolism	0.200
# Arthropathies and related disorders	0.157
# ----------------------------------------
# Bronchodilator Agents	0.175
# Tocolytic Agents	0.174
# Adrenergic beta-2 Receptor Agonists	0.173
# Antihypertensive Agents	0.167
# Glucocorticoids	0.157
# Anti-Inflammatory Agents	0.154
# ===== phenotype 18=================================================================
# proportion of pts: 0.184053946846
# lambda: 5035.74038773
# ----------------------------------------
# General symptoms	0.180
# Acute respiratory infections	0.172
# Symptoms involving skin and other integumentary tissue	0.169
# Symptoms involving respiratory system and other chest symptoms	0.166
# Hypertensive disease	0.163
# Other diseases of the upper respiratory tract	0.151
# ----------------------------------------
# Antihypertensive Agents	0.229
# Anti-Inflammatory Agents	0.214
# Anti-Allergic Agents	0.202
# Calcium Channel Blockers	0.202
# Hypnotics and Sedatives	0.153
# ===== phenotype 22=================================================================
# proportion of pts: 0.19000396668
# lambda: 4740.91425802
# ----------------------------------------
# Hypertensive disease	0.233
# General symptoms	0.208
# Disorders of lipoid metabolism	0.196
# Range name na	0.189
# Diabetes	0.174
# ----------------------------------------
# Analgesics, Non-Narcotic	0.266
# Vasodilator Agents	0.257
# Diuretics	0.245
# Calcium Channel Blockers	0.231
# ===== phenotype 38=================================================================
# proportion of pts: 0.197937326458
# lambda: 4733.33025906
# ----------------------------------------
# Hypertensive disease	0.250
# Disorders of lipoid metabolism	0.236
# Diabetes	0.182
# Ischemic heart disease	0.177
# Range name na	0.155
# ----------------------------------------
# Angiotensin-Converting Enzyme Inhibitors	0.284
# Vasodilator Agents	0.254
# Anti-Inflammatory Agents, Non-Steroidal	0.234
# Adrenergic alpha-1 Receptor Antagonists	0.228
# ===== phenotype 39=================================================================
# proportion of pts: 0.163427211424
# lambda: 4389.19038661
# ----------------------------------------
# Hypertensive disease	0.186
# Ischemic heart disease	0.181
# Other forms of heart disease	0.163
# Symptoms involving respiratory system and other chest symptoms	0.161
# Disorders of lipoid metabolism	0.157
# Range name na	0.153
# ----------------------------------------
# Vasodilator Agents	0.271
# Diuretics	0.260
# Vitamins	0.236
# Adrenergic beta-Antagonists	0.233
# ===== phenotype 15=================================================================
# proportion of pts: 0.154700515668
# lambda: 4331.30348995
# ----------------------------------------
# Hypertensive disease	0.209
# Disorders of lipoid metabolism	0.172
# Diseases of esophagus, stomach, and duodenum	0.168
# Other diseases of intestines and peritoneum	0.154
# Other symptoms involving abdomen and pelvis	0.149
# Ischemic heart disease	0.148
# ----------------------------------------
# Anti-Ulcer Agents	0.251
# Proton Pump Inhibitors	0.241
# Analgesics, Opioid	0.190
# Hypnotics and Sedatives	0.176
# Adjuvants, Anesthesia	0.142
# ===== phenotype 19=================================================================
# proportion of pts: 0.17572391908
# lambda: 4330.04332398
# ----------------------------------------
# Arthropathies and related disorders	0.213
# Hypertensive disease	0.209
# Range name na	0.204
# Rheumatism, excluding the back	0.193
# Disorders of lipoid metabolism	0.181
# ----------------------------------------
# Proton Pump Inhibitors	0.301
# Anti-Ulcer Agents	0.285
# Diuretics	0.214
# Anti-Allergic Agents	0.201
# ===== phenotype 1=================================================================
# proportion of pts: 0.163823879413
# lambda: 4304.02527471
# ----------------------------------------
# Hypertensive disease	0.262
# Disorders of lipoid metabolism	0.228
# Na	0.176
# Symptoms involving respiratory system and other chest symptoms	0.170
# Organic sleep disorders	0.164
# ----------------------------------------
# Serotonin Uptake Inhibitors	0.282
# Antidepressive Agents, Second-Generation	0.209
# Dermatologic Agents	0.185
# Anti-Allergic Agents	0.165
# Anti-Inflammatory Agents	0.160
# ===== phenotype 0=================================================================
# proportion of pts: 0.168187227291
# lambda: 4125.49658378
# ----------------------------------------
# Hypertensive disease	0.287
# Range name na	0.270
# General symptoms	0.241
# Symptoms involving respiratory system and other chest symptoms	0.202
# ----------------------------------------
# Anti-Bacterial Agents	0.223
# Histamine H1 Antagonists	0.218
# Antipruritics	0.212
# Anti-Ulcer Agents	0.186
# Antidepressive Agents, Second-Generation	0.161
# ===== phenotype 23=================================================================
# proportion of pts: 0.146767155891
# lambda: 3961.11972987
# ----------------------------------------
# Symptoms involving respiratory system and other chest symptoms	0.229
# Other symptoms involving abdomen and pelvis	0.209
# Symptoms involving skin and other integumentary tissue	0.196
# Arthropathies and related disorders	0.190
# Other diseases of respiratory system	0.176
# ----------------------------------------
# Antipyretics	0.221
# Antihypertensive Agents	0.207
# Anti-Inflammatory Agents, Non-Steroidal	0.207
# Cyclooxygenase Inhibitors	0.201
# Diuretics	0.164
# ===== phenotype 8=================================================================
# proportion of pts: 0.160650535502
# lambda: 3946.90094592
# ----------------------------------------
# Diabetes	0.244
# Hypertensive disease	0.227
# General symptoms	0.189
# Range name na	0.184
# Symptoms involving respiratory system and other chest symptoms	0.156
# ----------------------------------------
# Hypoglycemic Agents	0.272
# Platelet Aggregation Inhibitors	0.217
# Topoisomerase II Inhibitors	0.175
# Glucocorticoids	0.169
# Tocolytic Agents	0.167
# ===== phenotype 12=================================================================
# proportion of pts: 0.126537088457
# lambda: 3924.94336514
# ----------------------------------------
# Hypertensive disease	0.270
# Range name na	0.202
# Disorders of lipoid metabolism	0.201
# Arthropathies and related disorders	0.184
# General symptoms	0.143
# ----------------------------------------
# Enzyme Inhibitors	0.263
# Immunosuppressive Agents	0.262
# Antirheumatic Agents	0.248
# Antimetabolites, Antineoplastic	0.226
# ===== phenotype 35=================================================================
# proportion of pts: 0.16144387148
# lambda: 3892.79170812
# ----------------------------------------
# Other diseases of urinary system	0.275
# Other forms of heart disease	0.259
# Disorders of the eye and adnexa	0.257
# Disorders of thyroid gland	0.209
# ----------------------------------------
# Antihypertensive Agents	0.209
# Anti-Arrhythmia Agents	0.166
# Anti-Inflammatory Agents, Non-Steroidal	0.165
# Cyclooxygenase Inhibitors	0.159
# Diuretics	0.157
# Platelet Aggregation Inhibitors	0.144
# ===== phenotype 6=================================================================
# proportion of pts: 0.149147163824
# lambda: 3862.91171368
# ----------------------------------------
# Hypertensive disease	0.318
# Range name na	0.274
# General symptoms	0.224
# Symptoms involving respiratory system and other chest symptoms	0.184
# ----------------------------------------
# Anti-Arrhythmia Agents	0.235
# Adrenergic beta-1 Receptor Antagonists	0.209
# Sympatholytics	0.200
# Antihypertensive Agents	0.191
# Dermatologic Agents	0.165
# ===== phenotype 45=================================================================
# proportion of pts: 0.159857199524
# lambda: 3723.94737995
# ----------------------------------------
# Range name na	0.249
# Hypertensive disease	0.242
# Disorders of lipoid metabolism	0.176
# Arthropathies and related disorders	0.168
# Rheumatism, excluding the back	0.164
# ----------------------------------------
# Glucocorticoids	0.289
# Anti-Inflammatory Agents	0.264
# Antiemetics	0.227
# Antineoplastic Agents, Hormonal	0.220
# ===== phenotype 13=================================================================
# proportion of pts: 0.174930583102
# lambda: 3559.45995801
# ----------------------------------------
# Symptoms involving respiratory system and other chest symptoms	0.227
# Ischemic heart disease	0.217
# Other forms of heart disease	0.203
# Range name na	0.193
# Anemias	0.160
# ----------------------------------------
# Platelet Aggregation Inhibitors	0.344
# Cyclooxygenase Inhibitors	0.340
# Anti-Inflammatory Agents, Non-Steroidal	0.316
# ===== phenotype 14=================================================================
# proportion of pts: 0.16501388338
# lambda: 3339.92719312
# ----------------------------------------
# Hypertensive disease	0.262
# Disorders of lipoid metabolism	0.209
# Range name na	0.196
# Diabetes	0.177
# Arthropathies and related disorders	0.157
# ----------------------------------------
# Sodium Potassium Chloride Symporter Inhibitors	0.304
# Angiotensin II Type 1 Receptor Blockers	0.246
# Gout Suppressants	0.231
# Tubulin Modulators	0.219
# ===== phenotype 10=================================================================
# proportion of pts: 0.155493851646
# lambda: 3161.71306691
# ----------------------------------------
# Hypertensive disease	0.312
# Disorders of lipoid metabolism	0.253
# Osteopathies, chondropathies, and acquired musculoskeletal deformities	0.222
# Nephritis, nephrotic syndrome, and nephrosis	0.213
# ----------------------------------------
# Bone Density Conservation Agents	0.236
# Vitamins	0.225
# Angiotensin-Converting Enzyme Inhibitors	0.185
# Diuretics	0.184
# Calcium Channel Blockers	0.170
# ===== phenotype 25=================================================================
# proportion of pts: 0.154700515668
# lambda: 3132.70827286
# ----------------------------------------
# Other diseases of urinary system	0.217
# Range name na	0.216
# Symptoms involving respiratory system and other chest symptoms	0.207
# Other forms of heart disease	0.188
# Symptoms involving urinary system	0.171
# ----------------------------------------
# Anti-Bacterial Agents	0.287
# Bone Density Conservation Agents	0.261
# Vitamins	0.241
# Topoisomerase II Inhibitors	0.211
# ===== phenotype 40=================================================================
# proportion of pts: 0.176913923046
# lambda: 3049.15065737
# ----------------------------------------
# Diabetes	0.278
# Disorders of lipoid metabolism	0.259
# Hypertensive disease	0.238
# Disorders of the eye and adnexa	0.224
# ----------------------------------------
# Anti-Allergic Agents	0.350
# Anti-Inflammatory Agents	0.347
# Bronchodilator Agents	0.303
# ===== phenotype 29=================================================================
# proportion of pts: 0.139230464102
# lambda: 3022.28656175
# ----------------------------------------
# Arthropathies and related disorders	0.287
# Range name na	0.269
# Rheumatism, excluding the back	0.226
# Disorders of the eye and adnexa	0.219
# ----------------------------------------
# Analgesics	0.270
# Calcium Channel Blockers	0.253
# Anti-Anxiety Agents	0.243
# Anticonvulsants	0.234
# ===== phenotype 3=================================================================
# proportion of pts: 0.12534708449
# lambda: 2758.50250614
# ----------------------------------------
# Symptoms involving respiratory system and other chest symptoms	0.299
# Other forms of heart disease	0.267
# Range name na	0.246
# Anemias	0.188
# ----------------------------------------
# Anti-Anxiety Agents	0.223
# Hypnotics and Sedatives	0.220
# Antiemetics	0.202
# GABA Modulators	0.180
# Anticonvulsants	0.175
# ===== phenotype 11=================================================================
# proportion of pts: 0.113050376835
# lambda: 2041.30653225
# ----------------------------------------
# Other forms of heart disease	0.243
# Symptoms involving respiratory system and other chest symptoms	0.239
# Other diseases of respiratory system	0.189
# Ischemic heart disease	0.185
# Miscellaneous diagnostic and therapeutic procedures	0.144
# ----------------------------------------
# Hydroxymethylglutaryl-CoA Reductase Inhibitors	0.383
# Anticholesteremic Agents	0.372
# Anesthetics, Local	0.245
# ===== phenotype 4=================================================================
# proportion of pts: 0.140817136057
# lambda: 1919.44459486
# ----------------------------------------
# Arthropathies and related disorders	0.286
# Rheumatism, excluding the back	0.269
# Disorders of lipoid metabolism	0.245
# Symptoms involving head and neck	0.200
# ----------------------------------------
# Vasodilator Agents	0.374
# Calcium Channel Blockers	0.341
# Anticonvulsants	0.285
# ===== phenotype 33=================================================================
# proportion of pts: 0.158667195557
# lambda: 1754.05995586
# ----------------------------------------
# Hypertensive disease	0.257
# Disorders of lipoid metabolism	0.212
# Nonspecific findings on examination of blood	0.198
# Rheumatism, excluding the back	0.182
# Osteopathies, chondropathies, and acquired musculoskeletal deformities	0.150
# ----------------------------------------
# Antihypertensive Agents	0.547
# Calcium Channel Blockers	0.453
# ===== phenotype 27=================================================================
# proportion of pts: 0.127727092424
# lambda: 1345.32062675
# ----------------------------------------
# Hypertensive disease	0.251
# Rheumatism, excluding the back	0.204
# Organic sleep disorders	0.187
# Symptoms involving digestive system	0.179
# Dorsopathies	0.179
# ----------------------------------------
# Anti-Anxiety Agents	0.502
# Hypnotics and Sedatives	0.498
# ===== phenotype 37=================================================================
# proportion of pts: 0.152320507735
# lambda: 1098.38946831
# ----------------------------------------
# Arthropathies and related disorders	0.230
# Dorsopathies	0.211
# Rheumatism, excluding the back	0.204
# Range name na	0.191
# Osteopathies, chondropathies, and acquired musculoskeletal deformities	0.164
# ----------------------------------------
# Anti-Arrhythmia Agents	1.000
# ===== phenotype 24=================================================================
# proportion of pts: 0.142800476002
# lambda: 880.349823484
# ----------------------------------------
# Other diseases of skin and subcutaneous tissue	0.252
# Hypertensive disease	0.215
# General symptoms	0.192
# Range name na	0.172
# Symptoms involving urinary system	0.169
# ----------------------------------------
# Anti-Ulcer Agents	1.000
# ===== phenotype 42=================================================================
# proportion of pts: 0.120983736612
# lambda: 797.98490077
# ----------------------------------------
# Hypertensive disease	0.347
# Range name na	0.268
# Diabetes	0.195
# General symptoms	0.189
# ----------------------------------------
# Antioxidants	1.000
# ===== phenotype 41=================================================================
# proportion of pts: 0.12177707259
# lambda: 765.152373733
# ----------------------------------------
# Diabetes	0.234
# Anemias	0.216
# Disorders of the eye and adnexa	0.206
# Range name na	0.174
# Disorders of lipoid metabolism	0.170
# ----------------------------------------
# Anti-Ulcer Agents	1.000
# ===== phenotype 34=================================================================
# proportion of pts: 0.148353827846
# lambda: 647.986219983
# ----------------------------------------
# Other diseases of intestines and peritoneum	0.323
# Organic sleep disorders	0.307
# Symptoms involving head and neck	0.208
# Benign neoplasm of other parts of digestive system	0.162
# ----------------------------------------
# Antihypertensive Agents	1.000
# ===== phenotype 48=================================================================
# proportion of pts: 0.117810392701
# lambda: 537.720636086
# ----------------------------------------
# Certain traumatic complications and unspecified injuries	0.290
# Osteopathies, chondropathies, and acquired musculoskeletal deformities	0.260
# Fractures	0.231
# Hypertensive disease	0.219
# ----------------------------------------
# Antihypertensive Agents	1.000
# ===== phenotype 44=================================================================
# proportion of pts: 0.0
# lambda: 1.0
# ----------------------------------------
# ----------------------------------------
# ===== phenotype 43=================================================================
# proportion of pts: 0.0
# lambda: 1.0
# ----------------------------------------
# ----------------------------------------
# ===== phenotype 26=================================================================
# proportion of pts: 0.0
# lambda: 1.0
# ----------------------------------------
# ----------------------------------------
# ===== phenotype 20=================================================================
# proportion of pts: 0.0
# lambda: 1.0
# ----------------------------------------
# ----------------------------------------
# ===== phenotype 2=================================================================
# proportion of pts: 0.0
# lambda: 1.0
# ----------------------------------------
# ----------------------------------------

# %%
import sys
# R = int(sys.argv[1])
# alpha = float(sys.argv[2])
# gammaForTF = sys.argv[3]
# tensor_input = sys.argv[4]
# CODE_DIR = sys.argv[5]
# save_folder = sys.argv[6]

R = 50
alpha = 1
gammaForTF = '0.001,0.15,0.15'
tensor_input = '/nv/pcoc1/rchen87/tensor_factorization/github_tensor/htn_data_tensors/htn-tensor-subsetforanalysis-20140811-{0}.dat'
CODE_DIR = '/nv/pcoc1/rchen87/tensor_factorization/github_tensor/experiment_code/'
save_folder = '/nv/pcoc1/rchen87/tensor_factorization/github_tensor/htn_expt_run/output_20140829/'


gammaForTF = gammaForTF.split(',')
gammaForTF = [float(x) for x in gammaForTF]


#load required modules:                                                                                                                                                                                                                                                                                           
print "loading required modules"

execfile( CODE_DIR + 'setup_python_env.py')
pheWAS_xls_file = CODE_DIR + 'ICD9-2-PheWAS.xls'


#create output folder if it does not exist                                                                                                                                                                                                                                                                        
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

#do tensor factorization on the SUBSET - with GAMMA as set above ##################################################################################################                                                                                                                                               
#laod the tensor for the subset!                                                                                                                                                                                                                                                                                  
print "loading tensor data"

loaded_X, loaded_axisDict, loaded_classDict = tensorIO.loadSingleTensor(tensor_input)

startTime = time.time()#start time -- to time it                                                                                                                                                                                                                                                                  
##factorization                                                                                                                                                                                                                                                                                                   
print "running factorization"
spntf_htn_subset_analyzed_withGamma = SP_NTF.SP_NTF(loaded_X, R=R, alpha=alpha)
Yinfo_htn_subset_analyzed_withGamma = spntf_htn_subset_analyzed_withGamma.computeDecomp(gamma=gammaForTF)
marbleElapse = time.time() - startTime #elapsed time                                                                                                                                                                                                                                                              

#tensor decomposition factors ("phenotypes"):                                                                                                                                                                                                                                                                     
pheno_htn_subset_analyzed_withGamma_REG = spntf_htn_subset_analyzed_withGamma.M[0]
pheno_htn_subset_analyzed_withGamma_AUG = spntf_htn_subset_analyzed_withGamma.M[1]
pheno_htn_subset_analyzed_withGamma = (pheno_htn_subset_analyzed_withGamma_REG, pheno_htn_subset_analyzed_withGamma_AUG)


#string for saving the file based upon gamma                                                                                                                                                                                                                                                                      
gamma_str = '_gamma'
for num in gammaForTF:
    gamma_str = gamma_str + '-' + str(num)
gamma_str = gamma_str + '.pickle'

#save factorization in pickle                                                                                                                                                                                                                                                                                     
outfile_str = save_folder + "pheno_htn_subset_analyzed_REG" + gamma_str
with open(outfile_str, "wb") as output_file: ##IMPT! phenotype stored in this pickle                                                                                                                                                                                                                              
    pickle.dump(pheno_htn_subset_analyzed_withGamma, output_file)
output_file.close()
outfile_str = save_folder + "pheno_htn_subset_analyzed_AUG" + gamma_str
with open(outfile_str, "wb") as output_file: ##IMPT! phenotype stored in this pickle                                                                                                                                                                                                                              
    pickle.dump(pheno_htn_subset_analyzed_withGamma, output_file)
output_file.close()
outfile_str = save_folder + "Yinfo_htn_subset_analyzed" + gamma_str
with open(outfile_str, "wb") as output_file:
    pickle.dump(Yinfo_htn_subset_analyzed_withGamma, output_file)
output_file.close()


import operator

def calculateValues(TM, M):
    fms = TM.greedy_fms(M)
    fos = TM.greedy_fos(M)
    nnz = tensorTools.countTensorNNZ(M)
    return fms, fos, nnz

## load the tensor #######                                                                                                                                                                                                                                                                                        
loaded_X, loaded_axisDict, loaded_classDict = tensorIO.loadSingleTensor(tensor_input)

##read in the pickles:                                                                                                                                                                                                                                                                                            

outfile_str = save_folder + "pheno_htn_subset_analyzed_REG" + gamma_str
matrix_pkl = open(outfile_str, "rb")
pheno_htn_subset_analyzed_REG_withGamma = pickle.load(matrix_pkl)
matrix_pkl.close()

outfile_str = save_folder + "Yinfo_htn_subset_analyzed" + gamma_str
matrix_pkl = open(outfile_str, "rb")
Yinfo_htn_subset_analyzed_withGamma = pickle.load(matrix_pkl)
matrix_pkl.close()

#write output file                                                                                                                                                                                                                                                                                                
pheno_outstream = open(save_folder + "phenotypes"+gamma_str+".out", 'w+')


############################################################################################################## 

#load pheWAS dictionary                                                                                                                                                                                                                                                                                           

xls = pd.ExcelFile(pheWAS_xls_file)
df_pheWAS = xls.parse(xls.sheet_names[0])

d_jdrange_lookup = dict(zip(list(df_pheWAS.JD_X_RANGE), list(df_pheWAS.JD_X_NAME)))



#############################################################################################################                                                                                                                                                                                                     


#tensor with all phenotypes (factorization)                                                                                                                                                                                                                                                                       
ktensor_phenotypes = pheno_htn_subset_analyzed_REG_withGamma[0]
l_pts = loaded_axisDict[0].keys()
l_jdrange = loaded_axisDict[1].keys()
l_meds= loaded_axisDict[2].keys()

#will store all the data                                                                                                                                                                                                                                                                                          
d_pheno_nonzero_labels = OrderedDict()


#sort phenotypes by lambda values:                                                                                                                                                                                                                                                                                
d_lambda_phenoNumber = OrderedDict(zip( list(range(R)),
                                        list(ktensor_phenotypes.lmbda)
                                        ))
l_phenoNumbers_sorted_by_lambda = [tup[0] for tup in sorted(d_lambda_phenoNumber.iteritems(), key=operator.itemgetter(1))][::-1]  #get a sorted list of phenotype numbers, which are sorted by using the operator.itemgetter                                                                                      

#print phenotype feature names #################                                                                                                                                                                                                                                                                  
#for i in range(10):                                                 
for i in l_phenoNumbers_sorted_by_lambda:
    print "===== phenotype " + str(i) + "================================================================="
    pheno_outstream.write("===== phenotype " + str(i) + "=================================================================" + '\n')
    this_lmbda = ktensor_phenotypes.lmbda[i]
    this_pheno_pt_factor = ktensor_phenotypes.U[0][:,i]
    this_pheno_jdrange_factor = ktensor_phenotypes.U[1][:,i]
    this_pheno_med_factor = ktensor_phenotypes.U[2][:,i]

    this_pheno_pt_nnz = np.nonzero(this_pheno_pt_factor)[0]
    this_pheno_jdrange_nnz = np.nonzero(this_pheno_jdrange_factor)[0]
    this_pheno_med_nnz = np.nonzero(this_pheno_med_factor)[0]

    l_nonzero_pt_thisPheno = []
    l_nonzero_meds_thisPheno = []
    l_nonzero_jdrange_thisPheno = []
    l_nonzero_jdrange_names_thisPheno = []

    for j in this_pheno_pt_nnz:
        l_nonzero_pt_thisPheno.append(l_pts[j])
    for j in this_pheno_jdrange_nnz:
        l_nonzero_jdrange_thisPheno.append(l_jdrange[j])
        l_nonzero_jdrange_names_thisPheno.append(d_jdrange_lookup[l_jdrange[j]])
    for j in this_pheno_med_nnz:
        l_nonzero_meds_thisPheno.append(l_meds[j])

    #data                                                                                                                                                                                                                                                                                                         
    d_pheno_nonzero_labels[i] = dict() #for phenotype i                                                                                                                                                                                                                                                           
    d_pheno_nonzero_labels[i]['LAMBDA'] = this_lmbda #lambda value                                                                                                                                                                                                                                                
    d_pheno_nonzero_labels[i]['PERCENT_PTS'] = len(l_nonzero_pt_thisPheno) / float(len(this_pheno_pt_factor))
    d_pheno_nonzero_labels[i]['MEDS_NZ'] = l_nonzero_meds_thisPheno #for phenotype i                                                                                                                                                                                                                              
    d_pheno_nonzero_labels[i]['JDRANGE_NZ'] = l_nonzero_jdrange_thisPheno #for phenotype i                                                                                                                                                                                                                        
    d_pheno_nonzero_labels[i]['JDRANGE_NAMES_NZ'] = l_nonzero_jdrange_names_thisPheno #for phenotype i                                                                                                                                                                                                            

    print "proportion of pts: " + str(d_pheno_nonzero_labels[i]['PERCENT_PTS'])
    pheno_outstream.write("proportion of pts: " + str(d_pheno_nonzero_labels[i]['PERCENT_PTS']) + '\n')
    print "lambda: " + str(this_lmbda)
    pheno_outstream.write("lambda: " + str(this_lmbda) + '\n')


    print "----------------------------------------" #divider                                                                                                                                                                                                                                                     
    pheno_outstream.write("----------------------------------------" + '\n')
    #make ranking of JDRANGE by the weights:                                                                                                                                                                                                                                                                      
    nparr_jdrange_weights = this_pheno_jdrange_factor[this_pheno_jdrange_nnz]
    d_jdrangeindex_weights = OrderedDict(zip(this_pheno_jdrange_nnz, nparr_jdrange_weights))
    l_jdrangeindex_sorted = [tup[0] for tup in sorted(d_jdrangeindex_weights.iteritems(), key=operator.itemgetter(1))][::-1] #note: use slice [::-1] to reverse list!                                                                                                                                             
    for index_this_jdrange in l_jdrangeindex_sorted:
        print d_jdrange_lookup[l_jdrange[index_this_jdrange]] + '\t' + str("%.3f" %this_pheno_jdrange_factor[index_this_jdrange] )
        pheno_outstream.write(str(d_jdrange_lookup[l_jdrange[index_this_jdrange]]) + '\t' + str("%.3f" %this_pheno_jdrange_factor[index_this_jdrange])  +'\n')


    print "----------------------------------------" #divider between diagnostic codes and meds                                                                                                                                                                                                                   
    pheno_outstream.write("----------------------------------------" + '\n')
    #make ranking of MED by the weights:                                                                                                                                                                                                                                                                          
    nparr_med_weights = this_pheno_med_factor[this_pheno_med_nnz]
    d_medindex_weights = OrderedDict(zip(this_pheno_med_nnz, nparr_med_weights))
    l_medindex_sorted = [tup[0] for tup in sorted(d_medindex_weights.iteritems(), key=operator.itemgetter(1))][::-1]
    for index_this_med in l_medindex_sorted:
        print l_meds[index_this_med]  + '\t' + str("%.3f" %this_pheno_med_factor[index_this_med])
        pheno_outstream.write(l_meds[index_this_med]  + '\t' + str("%.3f" %this_pheno_med_factor[index_this_med]) + '\n')
pheno_outstream.close()

# %%
g = OrderedDict()

# %%
g(1) = 'fdsa'
# Out:
#   File "<ipython-input-13-aea6c85723c6>", line 1
#     g(1) = 'fdsa'
# SyntaxError: can't assign to function call

# %%
g
# Out:
# OrderedDict()

# %%
g()
